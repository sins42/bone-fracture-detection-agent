# %% [markdown]
# ## Imports and notes

# %%
# !pip install pdfplumber
# !pip install chromadb smolagents python-dotenv gradio sentence-transformers
# !pip install langchain langchain-huggingface langchain-community pypdf langchain_chroma
# %pip install tiktoken python-dotenv
# !pip install openai langchain
# !pip install --upgrade langchain langchain-community langchain-huggingface chromadb sentence-transformers
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.6-py3-none-any.whl.metadata (42 kB)
# Collecting pdfminer.six==20250327 (from pdfplumber)
#   Downloading pdfminer_six-20250327-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pdfplumber) (11.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pdfminer.six==20250327->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pdfminer.six==20250327->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.6-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20250327-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --------------------------- ------------ 3.9/5.6 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 16.3 MB/s eta 0:00:00
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250327 pdfplumber-0.11.6 pypdfium2-4.30.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting chromadb
#   Downloading chromadb-1.0.0-cp39-abi3-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: smolagents in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (1.12.0)
# Requirement already satisfied: python-dotenv in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# Collecting gradio
#   Downloading gradio-5.23.3-py3-none-any.whl.metadata (16 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.6.4)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.7.6)
# Collecting fastapi==0.115.9 (from chromadb)
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.24.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.21.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.21.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.31.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.65.5)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.23.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: huggingface-hub>=0.28.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (0.29.3)
# Requirement already satisfied: requests>=2.32.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (2.32.3)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (2.2.3)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (3.1.4)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (11.1.0)
# Requirement already satisfied: markdownify>=0.14.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (1.1.0)
# Requirement already satisfied: duckduckgo-search>=6.3.7 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from smolagents) (7.5.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (4.3.0)
# Requirement already satisfied: ffmpy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: packaging in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (24.0)
# Requirement already satisfied: pydub in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.11.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: fsspec in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==1.8.0->gradio) (2024.10.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.50.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: pyproject_hooks in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (2.0.2)
# Requirement already satisfied: click>=8.1.8 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents) (8.1.8)
# Requirement already satisfied: primp>=0.14.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents) (0.14.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from duckduckgo-search>=6.3.7->smolagents) (5.3.1)
# Requirement already satisfied: certifi in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.28.0->smolagents) (3.17.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.20.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from markdownify>=0.14.1->smolagents) (4.12.3)
# Requirement already satisfied: coloredlogs in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-asgi==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=2.2.3->smolagents) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=2.2.3->smolagents) (2024.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.32.3->smolagents) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: networkx in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents) (2.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-1.0.0-cp39-abi3-win_amd64.whl (17.9 MB)
#    ---------------------------------------- 0.0/17.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/17.9 MB 12.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 5.0/17.9 MB 16.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.9/17.9 MB 15.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.0/17.9 MB 14.1 MB/s eta 0:00:01
#    --------------------------- ------------ 12.3/17.9 MB 13.3 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/17.9 MB 13.0 MB/s eta 0:00:01
#    -------------------------------------- - 17.0/17.9 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 17.9/17.9 MB 12.0 MB/s eta 0:00:00
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
# Downloading gradio-5.23.3-py3-none-any.whl (46.5 MB)
#    ---------------------------------------- 0.0/46.5 MB ? eta -:--:--
#    -- ------------------------------------- 3.4/46.5 MB 16.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.8/46.5 MB 13.0 MB/s eta 0:00:04
#    ------ --------------------------------- 8.1/46.5 MB 12.3 MB/s eta 0:00:04
#    --------- ------------------------------ 10.5/46.5 MB 12.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.8/46.5 MB 12.0 MB/s eta 0:00:03
#    ------------- -------------------------- 15.2/46.5 MB 11.8 MB/s eta 0:00:03
#    --------------- ------------------------ 17.6/46.5 MB 11.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.7/46.5 MB 11.6 MB/s eta 0:00:03
#    ------------------ --------------------- 22.0/46.5 MB 11.6 MB/s eta 0:00:03
#    -------------------- ------------------- 24.4/46.5 MB 11.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.7/46.5 MB 11.5 MB/s eta 0:00:02
#    ------------------------- -------------- 29.1/46.5 MB 11.5 MB/s eta 0:00:02
#    --------------------------- ------------ 31.7/46.5 MB 11.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.8/46.5 MB 11.4 MB/s eta 0:00:02
#    ------------------------------- -------- 36.2/46.5 MB 11.4 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/46.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.6/46.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 42.2/46.5 MB 11.0 MB/s eta 0:00:01
#    -------------------------------------- - 44.3/46.5 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 46.5/46.5 MB 10.7 MB/s eta 0:00:00
# Downloading sentence_transformers-4.0.2-py3-none-any.whl (340 kB)
# Using cached onnxruntime-1.21.0-cp310-cp310-win_amd64.whl (11.8 MB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Using cached opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
# Installing collected packages: starlette, onnxruntime, fastapi, opentelemetry-sdk, opentelemetry-instrumentation, gradio, sentence-transformers, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.46.1
#     Uninstalling starlette-0.46.1:
#       Successfully uninstalled starlette-0.46.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.12
#     Uninstalling fastapi-0.115.12:
#       Successfully uninstalled fastapi-0.115.12
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.27.0
#     Uninstalling opentelemetry-sdk-1.27.0:
#       Successfully uninstalled opentelemetry-sdk-1.27.0
# Successfully installed chromadb-1.0.0 fastapi-0.115.9 gradio-5.23.3 onnxruntime-1.21.0 opentelemetry-exporter-otlp-proto-grpc-1.31.1 opentelemetry-instrumentation-0.52b1 opentelemetry-instrumentation-asgi-0.52b1 opentelemetry-instrumentation-fastapi-0.52b1 opentelemetry-sdk-1.31.1 sentence-transformers-4.0.2 starlette-0.45.3
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain
#   Downloading langchain-0.3.23-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.21-py3-none-any.whl.metadata (2.4 kB)
# Collecting pypdf
#   Using cached pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting langchain_chroma
#   Using cached langchain_chroma-0.2.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchain-core<1.0.0,>=0.3.51 (from langchain)
#   Downloading langchain_core-0.3.51-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.24-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.11.2-py3-none-any.whl.metadata (64 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: requests<3,>=2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0.2)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-huggingface) (0.29.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-huggingface) (4.0.2)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-huggingface) (4.50.0)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.11.16-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numpy<3,>=1.26.2 (from langchain-community)
#   Using cached numpy-2.2.4-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pypdf) (4.12.2)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 (from langchain_chroma)
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.3.2-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.19.0-cp310-cp310-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.21.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.31.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.65.5)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (13.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: filelock in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.51->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Collecting pydantic-core==2.33.1 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.1-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.5.2)
# Requirement already satisfied: scipy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.12.0)
# Requirement already satisfied: Pillow in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (11.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: pyproject_hooks in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.0.2)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.45.3)
# Requirement already satisfied: anyio in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (4.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.0.4)
# Requirement already satisfied: sniffio in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.14.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (5.29.4)
# Requirement already satisfied: sympy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.2.14)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.31.1)
# ...
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (24.0)
# Requirement already satisfied: pyproject_hooks in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (2.0.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (4.3.0)
# Requirement already satisfied: certifi in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.4)
# Requirement already satisfied: idna in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (3.6)
# Requirement already satisfied: sniffio in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2024.10.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.20.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: networkx in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: pyreadline3 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sindh\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Using cached chromadb-1.0.0-cp39-abi3-win_amd64.whl (17.9 MB)
# Installing collected packages: chromadb
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.6.3
#     Uninstalling chromadb-0.6.3:
#       Successfully uninstalled chromadb-0.6.3
# Successfully installed chromadb-1.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-chroma 0.2.2 requires chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0, but you have chromadb 1.0.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import zipfile
import pdfplumber
import os
from dotenv import load_dotenv
import re
import shutil
from io import BytesIO
import pandas as pd
import numpy as np
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
import torch
from langchain_community.llms import Ollama
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

# %%
def extract_zip(uploaded_zip_path, extract_to="../temp_pdfs"):
    """Extracts a zipped folder containing PDFs."""
    os.makedirs(extract_to, exist_ok=True)  # Ensure extraction folder exists

    with zipfile.ZipFile(uploaded_zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

    pdf_files = []
    for root, _, files in os.walk(extract_to):
        for file in files:
            if file.lower().endswith(".pdf"):
                pdf_files.append(os.path.join(root, file))

    return pdf_files

def pdf_to_markdown_string(pdf_path):
    """Extracts structured content from a PDF and chunks by major sections."""
    with pdfplumber.open(pdf_path) as pdf:
        sections = {}
        current_section = None
        first_page_skipped = False

        for page_num, page in enumerate(pdf.pages):
            if not first_page_skipped:
                first_page_skipped = True
                continue  # Skip the first page (assumed to be TOC)

            text = page.extract_text()
            if not text:
                continue

            lines = text.split("\n")

            for line in lines:
                # Detecting major section headings using regex patterns
                # Detects section headings based on patterns like "Chapter X", bold text, or all-uppercase words
                if re.match(r"^\s*Chapter \d+:?", line) or re.match(r"^[A-Z][A-Z\s]+$", line.strip()):
                    current_section = line.strip()
                    sections[current_section] = sections.get(current_section, "")
                elif current_section:
                    sections[current_section] += line.strip() + "\n"

    # Convert to a list of markdown chunks
    markdown_chunks = []
    for section, content in sections.items():
        markdown_chunks.append(f"## {section}\n\n{content.strip()}\n\n")

    return markdown_chunks

def load_and_process_pdfs(zip_path):
    """Processes a zipped folder of PDFs and splits into smaller chunks for vector storage."""
    pdf_files = extract_zip(zip_path)
    all_chunks = []

    for pdf in pdf_files:
        markdown_sections = pdf_to_markdown_string(pdf)
        
        # Use a text splitter to break sections into smaller chunks
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,  # Adjust chunk size as needed?? Will need to experiment with this and how it interacts with the prompts we try out too
            chunk_overlap=50 # Made overlapping size smaller 
        )

        for section in markdown_sections:
            chunks = text_splitter.split_text(section)
            for chunk in chunks:
                all_chunks.append(Document(page_content=chunk, metadata={"source": os.path.basename(pdf)}))

    return all_chunks

def create_vector_store(chunks, persist_dir: str):
    """Create and persist a Chroma vector store using OpenAI embeddings."""
    
    if os.path.exists(persist_dir):
        print(f"Removing existing vector store from {persist_dir}")
        shutil.rmtree(persist_dir)  # Try commenting this out if issues persist

    # Debugging info
    print(f"Total chunks received for vector store: {len(chunks)}")
    if chunks:
        print(f"Example chunk: {chunks[0].page_content[:300]}")

    try:
        # Initialize OpenAI Embeddings
        embedding_model = OpenAIEmbeddings(model = 'text-embedding-3-small')

        print("Building and saving the new vector store with OpenAI embeddings...")
        vector_db = Chroma.from_documents(
            documents=chunks,
            embedding=embedding_model,
            persist_directory=persist_dir
        )
        return vector_db

    except Exception as e:
        print(f"Error creating vector store: {e}")
        return None  # Return None if an error occurs


def query_vector_store(vector_db, query):
    """Finds the most relevant chunks based on the query."""
    results = vector_db.similarity_search(query, k=3)  # Retrieve top 3 most relevant results
    return [doc.page_content for doc in results]

# %%
base_dir = "..\data\<TODO.zip>"

# %%
torch.set_num_threads(1)

# Load environment variables from .env file
load_dotenv(dotenv_path="../.env")

# Get the API key
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key is None:
    print("Error: OPENAI_API_KEY not found in .env file.")
    exit()

# Set the API key as an environment variable
os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
def main():
    zip_file_path = base_dir 
    vector_db_dir = os.path.join(os.getcwd(), "/chroma_db") 

    print("Processing PDFs into chunks...")
    document_chunks = load_and_process_pdfs(zip_file_path)
    print(f"Generated {len(document_chunks)} document chunks.")

    print("Building the vector store...")
    vector_db = create_vector_store(document_chunks, vector_db_dir)
    print(f"Vector store successfully created at {vector_db_dir}")

    # Example query
    user_query = "..."

    results = query_vector_store(vector_db, user_query)

    print("\nTop Matching Results:")
    for idx, result in enumerate(results, 1):
        print(f"{idx}. {result[:300]}...")  # Display first 300 chars



    system_prompt =  """ 
        Context:
        <Documents>{context}</Documents>
       """
    
    similarity_threshold_retriever = vector_db.as_retriever(search_type="similarity_score_threshold",search_kwargs={"k": 3,"score_threshold": 0.3})

    prompt = ChatPromptTemplate.from_messages(
        [
            ('system', system_prompt),
            ('human', '{input}')
        ]
    )

    deepseek = Ollama(model="deepseek-r1:1.5b")

    question_answer_chain = create_stuff_documents_chain(deepseek, prompt)
    chain = create_retrieval_chain(similarity_threshold_retriever, question_answer_chain)

    print(chain.invoke({'input': user_query}))

# %%
if __name__ == "__main__":
    main()

# %%
# import sqlite3
# # 'c:/chroma_db/chroma.sqlite3'


# def read_chroma_db(db_file="c:/chroma_db/chroma.sqlite3"): #Default filename
#     try:
#         conn = sqlite3.connect(db_file)
#         cursor = conn.cursor()

#         # Example: Get table names
#         cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
#         tables = cursor.fetchall()

#         print("Tables in chroma.sqlite3:")
#         for table in tables:
#             print(table[0])

#         # Example: Read data from the first table (if any)
#         if tables:
#             first_table = tables[0][0]  # Get the name of the first table
#             cursor.execute(f"SELECT * FROM {first_table};")
#             rows = cursor.fetchall()

#             print(f"\nData from {first_table}:")
#             for row in rows:
#                 print(row)

#     except sqlite3.Error as e:
#         print(f"An error occurred: {e}")

#     finally:
#         if conn:
#             conn.close()

# read_chroma_db() #uses the default filename.
